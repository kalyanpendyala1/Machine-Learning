# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Hypothesis
#
# Steps in Data Driven Decision Making
#
# 1. Formulate a Hypothesis
#
# 2. Find the right Test
#
# 3. Execute a test
#
# 4. Make a decision
#
#
# An idea that can be tested.
#
# *Apples in newyork are costly* It is an idea but it has no other thing to compare. It is not hypothesis.
#
# *apples in newyork are costlyt 1.75 dollars* Accepted hypothesis.
#
# *Mean salary of a Data Scientis is 113,000 dollars* Null hypothesis
#
# anything other than null hypotheis is **Alternative Hypothesis**
#
# h0 = salary = $ 113,000
#
# h1 = salary != $ 113,000
#
# h0 is commonly accepted fact, opposite is Alternate hypothesis. Researchers work to nullify or disapprove null hypothesis.
#
# Null Hypothesis - Earth is flat.
#
# Alternative Hypothesis - Earth is round.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
data = pd.read_csv('mobile_price.csv')
X = data.iloc[:,0:20]
y = data.iloc[:,-1]

data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# 0        188        2     ...              20       756  2549     9     7
# 1        136        3     ...             905      1988  2631    17     3
# 2        145        5     ...            1263      1716  2603    11     2
# 3        131        6     ...            1216      1786  2769    16     8
# 4        141        2     ...            1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
# apply SelectKBest class to extract top 10 best features

best_features = SelectKBest(score_func=chi2, k=10)
fit = best_features.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

dfscores
# Out:
#                 0
# 0    14129.866576
# 1        0.723232
# 2        0.648366
# 3        0.631011
# 4       10.135166
# 5        1.521572
# 6       89.839124
# 7        0.745820
# 8       95.972863
# 9        9.097556
# 10       9.186054
# 11   17363.569536
# 12    9810.586750
# 13  931267.519053
# 14       9.614878
# 15      16.480319
# 16      13.236400
# 17       0.327643
# 18       1.928429
# 19       0.422091

# %%
# concat two dataframe for better visualization

featureScores = pd.concat([dfcolumns, dfscores], axis=1)
featureScores.columns = ['Specs', 'Score']

featureScores.nlargest(10,'Score')
# Out:
#             Specs          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# ### Feature Importance

# %%
from sklearn.tree import ExtraTreeClassifier

import matplotlib.pyplot as plt

model = ExtraTreeClassifier()
model.fit(X, y)

print(model.feature_importances_)
# Out:
# [0.05525323 0.01766331 0.03432449 0.02283651 0.03072059 0.01095181
#  0.04630272 0.03944738 0.03991555 0.04039975 0.03254943 0.04014618
#  0.06134542 0.35825451 0.03297456 0.03703733 0.03895476 0.01051658
#  0.02170398 0.02870192]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# ### Correlation Matrix with Heatmap

# %%
import seaborn as sns

corrmat = data.corr()
top_corr_features = corrmat.index

plt.figure(figsize=(20,20))

# plot heatmap

g = sns.heatmap(data[top_corr_features].corr(),annot=True, cmap='RdYlGn')
g = sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
